# %%
####################################################
##### Field Programmable Spin Arrays for Scalable Quantum Repeaters
##### Author: Hanfeng Wang and Kevin C. Chen
##### Date: 12-23-2022
##### 
####################################################

from matplotlib import pyplot as plt
import numpy as np
import math
#import scipy.io

# load the Meep and MPB modules in Python
import meep as mp
from meep import mpb

c =  299792458
SiV_omega = (1e-12)*c/(737e-9) # in THz


dx = 0.005
### define device parameters (normalized to a=1)
# note: these numbers can be arbitrary
#a = 0.186

a = 0.244
h = 0.091/a
#h1 = 0.35/a
h2 = 0.273/a
W1 = 0.41/a


air = 1.0
dmd = 2.4
hfo = 1.9
aln = 2.15
kcl = 1.49

#X = 1
X = 1 #0.2*b
Y = 15
Z = 20#5


X2 = 1/2 - 1/10
#Y1 = 0.2/a/1.1
####################################################
### define alligator geometry verticies (one periodicity)
xs = np.linspace(-X/2,X/2,int(1/dx))



####################################################

outputfields = False
outputepsilon = False
midgapfreq = False
runsim = True
#simtype = "TE"




geometry = [mp.Block(mp.Vector3(X,W1,h), center=mp.Vector3(0,0,0), material=mp.Medium(index=dmd)),
#            mp.Block(mp.Vector3(2*X2,W1,h1), center=mp.Vector3(0,0,h/2+h1/2), material=mp.Medium(index=kcl)),
            mp.Block(mp.Vector3(X2,X2,h2), center=mp.Vector3(0,0.25/a+X2/2,-h/2-h2/2), material=mp.Medium(index=1.78)),
            mp.Block(mp.Vector3(X2,X2,h2), center=mp.Vector3(0,-0.25/a-X2/2,-h/2-h2/2), material=mp.Medium(index=1.78)),
            mp.Block(mp.Vector3(X2,0.5/a,h2), center=mp.Vector3(0,0,-h/2-h2/2), material=mp.Medium(index=aln)),
            mp.Block(mp.Vector3(X,10,6), center=mp.Vector3(0,0,-3-h/2-h2), material=mp.Medium(index=1.45))]

if midgapfreq:
    midgaps = []
ms = mpb.ModeSolver(                    
                        geometry_lattice=mp.Lattice(size=(X,Y,Z)),
                        geometry=geometry,
                        default_material=mp.Medium(index=air),
                        k_points=mp.interpolate(21, [mp.Vector3(0.4,0,0), mp.Vector3(0.5,0,0)]),
                        resolution=20,
                        # resolution=12,
                        num_bands=5
                        )

# if midgapfreq:
#     midgaps.append((1e-12)*(c/(a*1e-6))*abs(freqs[0][1]+freqs[0][0])/2.)

# plt.figure(figsize=(10,8))
# plt.plot(Zs, midgaps, "k-")
# # plt.plot(resolutions, midgaps, "k-")
# # plt.xlabel("resolutions")
# plt.xlabel("Z")
# plt.ylabel("Frequency (THz)")
# plt.title("Midgap freq")
# plt.show()
if runsim:
    ms.run()
    freqs = ms.all_freqs

    ks = [k.x for k in ms.k_points] # kx wavevector
    plt.figure(figsize=(10,8))
    plt.plot(ks, (1e-12)*(c/(a*1e-6))*freqs, "k-")
    plt.plot([ks[0],ks[-1]],[NV_omega,NV_omega],"k:")
    plt.plot([ks[0],ks[-1]],[ks[0]*c*1e-12/(a*1e-6),ks[-1]*c*1e-12/(a*1e-6)],"k:")
    plt.xlabel("$k_x (2\pi/a)$")
    plt.ylabel("$f$ (THz)")
    plt.title('simtype')
    plt.show()


### Plot mode fields
if outputfields:

    ms.k_points = [mp.Vector3(0.5)]
    ms.run(mpb.fix_efield_phase)
    # ms.run_te_yodd(mpb.fix_efield_phase)
    # ms.run_tm_yeven(mpb.fix_efield_phase)

    md = mpb.MPBData(x=5, resolution=50)
    z0 = int(ms.resolution[0]*Z/2.)
    for i in range(1,5):
        ez1 = np.real(md.convert(ms.get_efield(i,bloch_phase=False)[:,:,z0,2]))
        maxabsz1 = np.max(abs(ez1))
        plt.figure(figsize=(10,10))
        plt.imshow(ez1.T, cmap='RdBu', vmin=-maxabsz1, vmax=+maxabsz1)
        plt.colorbar()
        plt.show()
        print(i)
    
    
### Plot epsilon to check device geometry
if outputepsilon:
    ms.init_params(mp.NO_PARITY,False)
    plt.figure(figsize=(10,10))
    md = mpb.MPBData(x=1, resolution=50)
    A = md.convert(ms.get_epsilon())
    plt.show()


    #eps = ms.get_epsilon()
    #from mayavi import mlab
    #s = mlab.contour3d(eps, colormap="YlGnBu")
    #mlab.show()
# Out:
# Initializing eigensolver data
# Computing 5 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 20 x 300 x 400.
# Solving for 5 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 15, 0)
#      (0, 0, 20)
# Cell volume = 300
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 0.0666667, -0)
#      (0, -0, 0.05)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1,1.68033,0.372951)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,1.22459,-0.745902)
#           size (0.4,0.4,1.11885)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-1.22459,-0.745902)
#           size (0.4,0.4,1.11885)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-0.745902)
#           size (0.4,2.04918,1.11885)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-4.30533)
#           size (1,10,6)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 5 and 17 object nodes (vs. 5 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 23 k-points
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.40454545454545454, 0.0, 0.0>
#   Vector3<0.4090909090909091, 0.0, 0.0>
#   Vector3<0.41363636363636364, 0.0, 0.0>
#   Vector3<0.4181818181818182, 0.0, 0.0>
#   Vector3<0.42272727272727273, 0.0, 0.0>
#   Vector3<0.4272727272727273, 0.0, 0.0>
#   Vector3<0.4318181818181818, 0.0, 0.0>
#   Vector3<0.4363636363636364, 0.0, 0.0>
#   Vector3<0.4409090909090909, 0.0, 0.0>
#   Vector3<0.44545454545454544, 0.0, 0.0>
#   Vector3<0.45, 0.0, 0.0>
#   Vector3<0.4545454545454546, 0.0, 0.0>
#   Vector3<0.4590909090909091, 0.0, 0.0>
#   Vector3<0.4636363636363636, 0.0, 0.0>
#   Vector3<0.4681818181818182, 0.0, 0.0>
#   Vector3<0.4727272727272727, 0.0, 0.0>
#   Vector3<0.4772727272727273, 0.0, 0.0>
#   Vector3<0.4818181818181818, 0.0, 0.0>
#   Vector3<0.48636363636363633, 0.0, 0.0>
#   Vector3<0.4909090909090909, 0.0, 0.0>
#   Vector3<0.4954545454545455, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 4.137469053268433
# solve_kpoint (0.4,0,0):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5
# Solving for bands 1 to 5...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 9.025852670633912 (192.278% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.7956800485045589 (167.594% change)
#     linmin: converged after 8 iterations.
#     iteration    3: trace = 0.4999205576763474 (45.656% change)
#     linmin: converged after 8 iterations.
#     iteration    4: trace = 0.4347500483719948 (13.9451% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 0.4191935058898085 (3.64346% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.4103894948618104 (2.12251% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.4044509563778148 (1.4576% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 0.400687610271701 (0.934832% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 0.3978402993979003 (0.71314% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 0.3960793284913953 (0.443614% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 0.3947899310359488 (0.326071% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 0.3941134066940247 (0.17151% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 0.393681182258193 (0.10973% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 0.3934754142269088 (0.0522813% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 0.3933688832707942 (0.027078% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 0.3933068234751133 (0.0157777% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 0.3932771147363635 (0.00755386% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 0.3932610824108022 (0.00407668% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 0.393252099006674 (0.00228436% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 0.3932453310460408 (0.00172104% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 0.3932414053602089 (0.000998284% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 0.393238654964059 (0.000699419% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 0.3932370830708917 (0.000399731% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 0.393236033245408 (0.00026697% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 0.3932353342805139 (0.000177747% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 0.3932348626185121 (0.000119944% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 0.3932345494888332 (7.96292e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 0.3932343121278895 (6.03612e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 0.3932341381441919 (4.42443e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 0.3932340217238253 (2.96059e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 0.3932339410542158 (2.05144e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 0.3932338905687522 (1.28385e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 0.3932338591998073 (7.97717e-06% change)
# Finished solving for bands 1 to 5 after 33 iterations.
# freqs:, 1, 0.4, 0, 0, 0.4, 0.270321, 0.277625, 0.282188, 0.284089, 0.287661
# elapsed time for k point: 146.91987919807434
# solve_kpoint (0.404545,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4007422100211977 (0.00731631% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4007374502867653 (0.00118774% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4007356046237665 (0.000460568% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4007345665824513 (0.000259034% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4007341842843238 (9.53994e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4007340422832892 (3.54352e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4007339791260269 (1.57604e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4007339508487295 (7.05638e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# freqs:, 2, 0.404545, 0, 0, 0.404545, 0.272309, 0.279998, 0.285218, 0.286938, 0.290689
# elapsed time for k point: 34.42586088180542
# solve_kpoint (0.409091,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4082722864492912 (0.00756015% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4082672727700065 (0.00122803% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4082654505794875 (0.000446324% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4082644510422928 (0.000244826% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4082640637105405 (9.48728e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4082639131131175 (3.68873e-05% change)
#     linmin: converged after 1 iterations.
#     iteration    7: trace = 0.4082638480226948 (1.59432e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4082638183014214 (7.27992e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# freqs:, 3, 0.409091, 0, 0, 0.409091, 0.274266, 0.282283, 0.288255, 0.289821, 0.293719
# elapsed time for k point: 35.42184638977051
# solve_kpoint (0.413636,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4158285706123118 (0.0078199% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4158232781453763 (0.00127276% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4158214898227975 (0.000430069% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4158205364429906 (0.000229276% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4158201622473973 (8.99897e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4158200103167717 (3.65376e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4158199417932503 (1.64791e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4158199120714051 (7.14777e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# freqs:, 4, 0.413636, 0, 0, 0.413636, 0.276191, 0.284482, 0.291297, 0.292734, 0.296751
# elapsed time for k point: 36.075944900512695
# solve_kpoint (0.418182,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4234072508337302 (0.00810701% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4234016215384221 (0.00132953% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4233998448966986 (0.000419612% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4233989297825349 (0.000216135% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4233985700140929 (8.49715e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4233984181681875 (3.58636e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4233983485503105 (1.64426e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4233983190849747 (6.95925e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# freqs:, 5, 0.418182, 0, 0, 0.418182, 0.278084, 0.286594, 0.294344, 0.295673, 0.299785
# elapsed time for k point: 35.45193600654602
# solve_kpoint (0.422727,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4310039788530894 (0.00841919% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4309979566261269 (0.00139727% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4309961750209167 (0.000413368% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4309952948638408 (0.000204215% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4309949509407269 (7.97974e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4309947986882498 (3.53258e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4309947251586868 (1.70604e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4309946949988746 (6.99772e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# freqs:, 6, 0.422727, 0, 0, 0.422727, 0.279944, 0.288619, 0.297393, 0.298635, 0.30282
# elapsed time for k point: 35.32029604911804
# solve_kpoint (0.427273,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4386139328797338 (0.00875853% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4386074514844195 (0.00147771% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4386056416305882 (0.000412637% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4386047881556207 (0.000194588% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4386044600527237 (7.48061e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4386043073749765 (3.48099e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4386042286684781 (1.79448e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4386041966534971 (7.29929e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# freqs:, 7, 0.427273, 0, 0, 0.427273, 0.281769, 0.290556, 0.300446, 0.301614, 0.305857
# elapsed time for k point: 35.341376304626465
# solve_kpoint (0.431818,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4462317178593179 (0.00912727% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4462246996567181 (0.00157278% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4462228328154156 (0.000418364% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4462219937124096 (0.000188046% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4462216792508706 (7.0472e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4462215250026322 (3.45676e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4462214375853283 (1.95906e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4462214015999422 (8.06447e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# freqs:, 8, 0.431818, 0, 0, 0.431818, 0.283558, 0.292406, 0.303499, 0.304609, 0.308895
# elapsed time for k point: 35.028284788131714
# solve_kpoint (0.436364,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4538512663763457 (0.0095282% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4538436185493096 (0.00168511% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.453841656847449 (0.000432243% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4538408131972589 (0.000185891% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4538405066169983 (6.75524e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4538403477745836 (3.49996e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4538402464815097 (2.23191e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4538402031520274 (9.5473e-06% change)
# Finished solving for bands 1 to 5 after 8 iterations.
# freqs:, 9, 0.436364, 0, 0, 0.436364, 0.285308, 0.294164, 0.306554, 0.307618, 0.311935
# elapsed time for k point: 35.38558506965637
# solve_kpoint (0.440909,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4614657037679427 (0.00996464% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4614573143820108 (0.001818% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4614552078101628 (0.000456505% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.461454332057443 (0.000189781% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4614540223544618 (6.71146e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4614538518726715 (3.69445e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4614537268540697 (2.70923e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4614536702167591 (1.22737e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.4614536311446784 (8.46717e-06% change)
# Finished solving for bands 1 to 5 after 9 iterations.
# freqs:, 10, 0.440909, 0, 0, 0.440909, 0.287015, 0.295829, 0.309607, 0.310636, 0.314976
# elapsed time for k point: 39.41665291786194
# solve_kpoint (0.445455,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4690670965134642 (0.0104418% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4690578227319401 (0.00197709% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4690555047293152 (0.000494184% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4690545533362275 (0.000202832% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4690542293244662 (6.90777e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4690540416546749 (4.00103e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4690538988352454 (3.04484e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4690538310201702 (1.44578e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.4690537879538579 (9.18153e-06% change)
# Finished solving for bands 1 to 5 after 9 iterations.
# freqs:, 11, 0.445455, 0, 0, 0.445455, 0.288674, 0.297396, 0.312659, 0.313664, 0.318018
# elapsed time for k point: 39.52872848510742
# solve_kpoint (0.45,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4766463912217511 (0.0109629% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4766360682914389 (0.00216577% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4766334432936415 (0.000550736% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4766323581550745 (0.000227668% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4766319837120074 (7.85602e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.476631752399545 (4.85306e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.476631534700904 (4.56744e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4766314203046418 (2.4001e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.4766313553911128 (1.36192e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.476631316964949 (8.06203e-06% change)
# Finished solving for bands 1 to 5 after 10 iterations.
# freqs:, 12, 0.45, 0, 0, 0.45, 0.290279, 0.298863, 0.315707, 0.3167, 0.321062
# elapsed time for k point: 43.17707538604736
# solve_kpoint (0.454545,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 0.4841925473727374 (0.0115438% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4841809303415172 (0.00239929% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4841778419749636 (0.000637856% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4841765163746331 (0.000273784% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4841760509172592 (9.61339e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4841757028495881 (7.18887e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4841753736641754 (6.79889e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4841752053587721 (3.47613e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.4841751207785739 (1.74689e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.4841750735498245 (9.75448e-06% change)
# Finished solving for bands 1 to 5 after 10 iterations.
# freqs:, 13, 0.454545, 0, 0, 0.454545, 0.291824, 0.300224, 0.318747, 0.319742, 0.324106
# elapsed time for k point: 43.08047652244568
# solve_kpoint (0.459091,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.4916920861536217 (0.0121945% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4916788676943707 (0.0026884% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4916750873054002 (0.000768877% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4916733371337184 (0.000355962% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4916726365106878 (0.000142498% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4916720213592267 (0.000125114% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4916713551145099 (0.000135506% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4916710050306107 (7.12029e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.4916708495083912 (3.16314e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.4916707792794255 (1.42837e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.4916707363467774 (8.73199e-06% change)
# Finished solving for bands 1 to 5 after 11 iterations.
# freqs:, 14, 0.459091, 0, 0, 0.459091, 0.293298, 0.301476, 0.321774, 0.32279, 0.32715
# elapsed time for k point: 47.21980285644531
# solve_kpoint (0.463636,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.4991263412918579 (0.0129549% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.4991109893500192 (0.00307581% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.4991060660035481 (0.000986428% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.4991034643304355 (0.000521268% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.4991021827568801 (0.000256775% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.4991007479638945 (0.000287475% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.4990991562549832 (0.000318916% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.4990983875322546 (0.000154022% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.4990980750032851 (6.26187e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.4990979423840882 (2.65718e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.4990978594904654 (1.66087e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.4990977995632255 (1.20071e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.4990977415779472 (1.1618e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.4990976943378245 (9.4651e-06% change)
# Finished solving for bands 1 to 5 after 14 iterations.
# freqs:, 15, 0.463636, 0, 0, 0.463636, 0.294692, 0.302613, 0.324775, 0.325843, 0.330194
# elapsed time for k point: 59.660820960998535
# solve_kpoint (0.468182,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.5064644638522769 (0.0139346% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5064458808701227 (0.00366923% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5064386042147897 (0.00143682% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5064337963460799 (0.000949353% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5064304496715331 (0.000660834% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5064256478216949 (0.00094818% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5064206134806655 (0.000994098% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.5064181818905611 (0.000480153% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5064170841008107 (0.000216776% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5064164591269938 (0.000123411% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.5064159030257631 (0.000109811% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.5064153400088673 (0.000111177% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.506414774883602 (0.000111593% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.5064142835836694 (9.70154e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.50641358840359 (0.000137275% change)
#     large trace change predicted (0.000329966%)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 0.5064119190539551 (0.000329642% change)
#     large trace change predicted (0.00147295%)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 0.5064047832365323 (0.0014091% change)
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration   18: trace = 0.5063720576960337 (0.00646254% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 0.5063582013128538 (0.00273644% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 0.5063460942000768 (0.00239105% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 0.5063342901699912 (0.00233124% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 0.5063221521079617 (0.00239727% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 0.5063094200051192 (0.00251466% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 0.5062961130965242 (0.00262825% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 0.5062824323027237 (0.00270217% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 0.50626875256333 (0.00270203% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 0.5062554775337382 (0.00262217% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 0.5062427754041067 (0.00250907% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 0.5062306003357903 (0.00240502% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 0.5062189127730657 (0.00230877% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 0.5062077576326606 (0.00220364% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 0.5061971716135849 (0.00209126% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 0.5061871052194463 (0.00198865% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 0.5061774539169379 (0.00190669% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 0.5061681414137131 (0.00183979% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 0.506159172833165 (0.00177187% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 0.5061506262760941 (0.00168853% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 0.5061426013887309 (0.00158549% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 0.5061351668557309 (0.00146887% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 0.5061283376180276 (0.0013493% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 0.5061220834114003 (0.0012357% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 0.506116351345467 (0.00113255% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 0.5061110858797465 (0.00104037% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 0.5061062391426109 (0.000957648% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 0.5061017724212066 (0.00088257% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 0.506097652950305 (0.000813964% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 0.5060938500646748 (0.000751416% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 0.5060903330884916 (0.000694928% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 0.5060870714031395 (0.000644489% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 0.506084035854428 (0.000599809% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 0.5060812002878687 (0.000560297% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 0.506078542289661 (0.000525213% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 0.5060760427753557 (0.0004939% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 0.5060736846164344 (0.00046597% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 0.5060714508586167 (0.000441391% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 0.5060693231798249 (0.000420431% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 0.5060672810705655 (0.000403524% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 0.5060653019169697 (0.000391086% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 0.5060633618921841 (0.000383355% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 0.5060614374162932 (0.000380284% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 0.5060595069169461 (0.000381476% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 0.5060575526267105 (0.000386179% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 0.5060555621258219 (0.000393336% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 0.5060535292904945 (0.000401703% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 0.5060514543230155 (0.00041003% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 0.5060493427065631 (0.000417274% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 0.5060472032430893 (0.000422779% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 0.5060450456666346 (0.00042636% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 0.5060428784932322 (0.000428258% change)
#     resetting CG direction...
#     large trace change predicted (0.0188289%)
#     linmin: converged after 4 iterations.
#     iteration   70: trace = 0.5059475560102368 (0.0188386% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 0.5058963360203539 (0.0101241% change)
#     linmin: converged after 4 iterations.
#     iteration   72: trace = 0.5058650645466695 (0.00618159% change)
#     linmin: converged after 4 iterations.
#     iteration   73: trace = 0.5058436936773201 (0.00422471% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 0.5058294165074908 (0.00282249% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 0.5058203398677437 (0.00179442% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 0.5058137504159177 (0.00130273% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 0.5058079015694888 (0.00115633% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 0.5058041230876764 (0.000747022% change)
#     linmin: converged after 2 iterations.
#     iteration   79: trace = 0.5057989090776287 (0.00103084% change)
#     linmin: converged after 3 iterations.
#     iteration   80: trace = 0.5057894778855332 (0.00186463% change)
#     linmin: converged after 3 iterations.
#     iteration   81: trace = 0.5057825785075521 (0.00136409% change)
#     linmin: converged after 3 iterations.
#     iteration   82: trace = 0.5057777105635207 (0.000962462% change)
#     linmin: converged after 3 iterations.
#     iteration   83: trace = 0.5057730862192522 (0.000914308% change)
#     linmin: converged after 3 iterations.
#     iteration   84: trace = 0.505769998952466 (0.000610407% change)
#     linmin: converged after 3 iterations.
#     iteration   85: trace = 0.5057669905152147 (0.000594825% change)
#     linmin: converged after 3 iterations.
#     iteration   86: trace = 0.5057628603727767 (0.000816613% change)
#     linmin: converged after 3 iterations.
#     iteration   87: trace = 0.5057588193998654 (0.000798989% change)
#     linmin: converged after 3 iterations.
#     iteration   88: trace = 0.5057554010760549 (0.000675883% change)
#     linmin: converged after 2 iterations.
#     iteration   89: trace = 0.5057538295262136 (0.000310734% change)
#     linmin: converged after 2 iterations.
#     iteration   90: trace = 0.5057531411160915 (0.000136116% change)
#     linmin: converged after 2 iterations.
#     iteration   91: trace = 0.5057527890545408 (6.96114e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   92: trace = 0.5057525693191783 (4.34472e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   93: trace = 0.5057524094706947 (3.16061e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   94: trace = 0.5057523324792511 (1.52232e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   95: trace = 0.5057522931717066 (7.77209e-06% change)
# Finished solving for bands 1 to 5 after 95 iterations.
# freqs:, 16, 0.468182, 0, 0, 0.468182, 0.295991, 0.30363, 0.327714, 0.328899, 0.332233
# elapsed time for k point: 383.8425843715668
# solve_kpoint (0.472727,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.511434504111175 (0.0212573% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.5113834167291472 (0.00998954% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.5113295673221164 (0.0105307% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.511270765776662 (0.0115004% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.5112306607288858 (0.0078445% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.5112026083390455 (0.00548738% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.5111896686050748 (0.00253127% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.5111839351027817 (0.00112161% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5111799299214556 (0.000783514% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5111763726617312 (0.000695894% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.5111740569719864 (0.000453013% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.5111729718129097 (0.000212288% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.5111725134325605 (8.96723e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.5111723139345691 (3.90275e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.5111721911738448 (2.40155e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.5111721077506641 (1.632e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 0.5111720636529077 (8.62679e-06% change)
# Finished solving for bands 1 to 5 after 17 iterations.
# freqs:, 17, 0.472727, 0, 0, 0.472727, 0.29718, 0.304524, 0.330423, 0.33196, 0.332784
# elapsed time for k point: 71.84373164176941
# solve_kpoint (0.477273,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.5162628286751073 (0.0190575% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.516223323814641 (0.00765238% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.51618551836497 (0.00732374% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.5161420697011541 (0.00841761% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.5161140550559919 (0.00542785% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.5160948848268939 (0.00371441% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5160847416587248 (0.00196539% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.5160794440573687 (0.0010265% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5160754160787439 (0.000780499% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5160719800907336 (0.000665794% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.5160699460901114 (0.000394132% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.5160689652161687 (0.000190066% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.5160684725116913 (9.54726e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.5160681707484199 (5.84735e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.5160678970683028 (5.30318e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.516067655478572 (4.68136e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 0.5160675147596822 (2.72675e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 0.5160674313707462 (1.61585e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 0.5160673868765809 (8.62177e-06% change)
# Finished solving for bands 1 to 5 after 19 iterations.
# freqs:, 18, 0.477273, 0, 0, 0.477273, 0.29824, 0.305288, 0.331738, 0.334108, 0.335024
# elapsed time for k point: 79.64822268486023
# solve_kpoint (0.481818,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.5206912096494135 (0.018119% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5206555039564837 (0.0068576% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5206201642314856 (0.00678778% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5205727672743481 (0.00910436% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.520539447634225 (0.00640078% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.5205150127875016 (0.00469425% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.5204984024140077 (0.00319119% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.5204870839592182 (0.00217457% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5204777064949314 (0.00180169% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5204700878418893 (0.00146379% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.5204658909623039 (0.000806367% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.5204637303690438 (0.000415128% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.5204624719715947 (0.000241784% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.5204616523637433 (0.000157477% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.5204609998048311 (0.000125381% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.5204605401217448 (8.83223e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 0.5204603249126177 (4.13498e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 0.5204602086479999 (2.23388e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 0.5204601531107413 (1.06708e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 0.52046012802254 (4.82039e-06% change)
# Finished solving for bands 1 to 5 after 20 iterations.
# freqs:, 19, 0.481818, 0, 0, 0.481818, 0.299151, 0.30592, 0.331606, 0.336325, 0.33809
# elapsed time for k point: 84.55239343643188
# solve_kpoint (0.486364,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.5244755499994185 (0.020446% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5244283065737679 (0.00900815% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 0.524371258698332 (0.0108787% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.5242902586664979 (0.0154483% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.5242347143444958 (0.0105948% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.5241940006574978 (0.00776661% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.524167110961222 (0.00512985% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 0.5241496743264149 (0.0033266% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5241381808296445 (0.00219281% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5241312793650214 (0.00131673% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.5241281915736742 (0.000589127% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.5241267563960499 (0.000273822% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.524125981030602 (0.000147935% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.5241255912008514 (7.43771e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.5241253688890165 (4.24158e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 0.5241252288707621 (2.67147e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 0.524125159248244 (1.32836e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 0.5241251127395004 (8.8736e-06% change)
# Finished solving for bands 1 to 5 after 18 iterations.
# freqs:, 20, 0.486364, 0, 0, 0.486364, 0.29989, 0.306415, 0.331264, 0.337898, 0.341159
# elapsed time for k point: 75.50438022613525
# solve_kpoint (0.490909,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 2 iterations.
#     iteration    1: trace = 0.5273321080345218 (0.0226609% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 0.5272852904593615 (0.00887859% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5272411123316554 (0.00837876% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.5271911205094104 (0.00948223% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 0.5271618005248423 (0.0055617% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.5271418198506124 (0.00379031% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.527129081839256 (0.00241646% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.5271215895215589 (0.00142135% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5271171094741974 (0.000849911% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5271146721311443 (0.000462392% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.5271136593197548 (0.000192143% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.5271132247305441 (8.2447e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.527113010818979 (4.05817e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.5271129249011268 (1.62997e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 0.5271128893903452 (6.73685e-06% change)
# Finished solving for bands 1 to 5 after 15 iterations.
# freqs:, 21, 0.490909, 0, 0, 0.490909, 0.300437, 0.306771, 0.330951, 0.338701, 0.34423
# elapsed time for k point: 63.354288816452026
# solve_kpoint (0.495455,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5298009612770224 (0.0224544% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.529764053433362 (0.0069666% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.5297406356619602 (0.00442051% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.529719502694314 (0.00398938% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5297087703396434 (0.00202607% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.5297022850812102 (0.00122431% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5296983848566588 (0.000736308% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.5296961466943627 (0.000422536% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5296947934439018 (0.000255477% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5296940447565731 (0.000141343% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.5296937248755141 (6.03898e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.5296935877570018 (2.58864e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.529693517283787 (1.33045e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.5296934876291175 (5.59846e-06% change)
# Finished solving for bands 1 to 5 after 14 iterations.
# freqs:, 22, 0.495455, 0, 0, 0.495455, 0.300774, 0.306986, 0.330741, 0.339086, 0.347302
# elapsed time for k point: 59.24456858634949
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 5...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 0.5320548814718192 (0.0221481% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 0.5320221352519642 (0.00615486% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 0.532005442611561 (0.00313763% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 0.5319923518398301 (0.00246068% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 0.5319864010613605 (0.00111859% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 0.531983232192617 (0.000595669% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 0.5319814418192512 (0.000336548% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.5319804849437091 (0.00017987% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.5319798862347987 (0.000112543% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.5319794668457133 (7.88355e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 0.531979195129741 (5.10764e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 0.5319789600042293 (4.41983e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 0.5319786497123379 (5.83279e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 0.5319781842544188 (8.74956e-05% change)
#     large trace change predicted (0.000184722%)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 0.5319772019421687 (0.000184653% change)
#     large trace change predicted (0.000483146%)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 0.5319746409712753 (0.000481407% change)
#     large trace change predicted (0.000999964%)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 0.5319693932877477 (0.000986459% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 0.5319602146491608 (0.00172542% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 0.5319519031852777 (0.00156243% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 0.5319471634809682 (0.000891006% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 0.531944119265486 (0.000572279% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 0.5319416980444835 (0.000455166% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 0.5319394746603022 (0.000417976% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 0.5319372501657076 (0.000418187% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 0.5319355760922235 (0.000314713% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 0.5319342363318661 (0.000251865% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 0.5319331577207725 (0.000202772% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 0.5319324446150004 (0.000134059% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 0.5319319370082066 (9.5427e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 0.5319315661901439 (6.97116e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 0.5319313543256928 (3.98293e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 0.5319312461140545 (2.03432e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 0.5319311775764569 (1.28847e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 0.5319311416928829 (6.74591e-06% change)
# Finished solving for bands 1 to 5 after 34 iterations.
# freqs:, 23, 0.5, 0, 0, 0.5, 0.300888, 0.307058, 0.330668, 0.339204, 0.350304
# elapsed time for k point: 140.84612369537354
# Band 1 range: 0.2703205062128532 at Vector3<0.4, 0.0, 0.0> to 0.3008877555291284 at Vector3<0.5, 0.0, 0.0>
# Band 2 range: 0.2776247318174978 at Vector3<0.4, 0.0, 0.0> to 0.30705766035510285 at Vector3<0.5, 0.0, 0.0>
# Band 3 range: 0.28218789953731016 at Vector3<0.4, 0.0, 0.0> to 0.3317382190903693 at Vector3<0.4772727272727273, 0.0, 0.0>
# Band 4 range: 0.28408883240899335 at Vector3<0.4, 0.0, 0.0> to 0.3392039762408205 at Vector3<0.5, 0.0, 0.0>
# Band 5 range: 0.2876607655887534 at Vector3<0.4, 0.0, 0.0> to 0.3503035327033437 at Vector3<0.5, 0.0, 0.0>
# total elapsed time for run: 1664.4384043216705
# done

# %%
NV_omega = (1e-12)*2.997e8/(737.5e-9)
plt.figure(figsize=(10,8))
plt.plot(ks, (1e-12)*(c/(a*1e-6))*freqs[:,0], "k-")
plt.plot(ks, (1e-12)*(c/(a*1e-6))*freqs[:,2], "k-")
plt.plot([ks[0],ks[-1]],[NV_omega,NV_omega],"k:")
#plt.plot([ks[0],ks[-1]],[ks[0]*c*1e-12/(a*1e-6),ks[-1]*c*1e-12/(a*1e-6)],"k:")
plt.plot([ks[0],ks[-1]],[ks[0]*c*1e-12/(a*1e-6)/1.45,ks[-1]*c*1e-12/(a*1e-6)/1.45],"k:")
plt.xlabel("$k_x (2\pi/a)$")
plt.ylabel("$f$ (THz)")
plt.title('simtype')
plt.show()

# %%
freqs[:,0]
# Out:
# array([0.27032051, 0.27230947, 0.27426624, 0.27619118, 0.27808401,
#        0.27994389, 0.28176938, 0.28355838, 0.28530807, 0.28701475,
#        0.28867374, 0.29027914, 0.29182364, 0.29329819, 0.29469174,
#        0.29599089, 0.29717973, 0.29823983, 0.29915056, 0.29989015,
#        0.30043736, 0.30077403, 0.30088776])

# %%
freqs[:,2]
# Out:
# array([0.2821879 , 0.28521796, 0.28825479, 0.29129704, 0.29434358,
#        0.29739341, 0.30044565, 0.30349939, 0.3065537 , 0.30960742,
#        0.31265917, 0.31570682, 0.31874708, 0.32177395, 0.32477474,
#        0.32771434, 0.33042255, 0.33173822, 0.33160623, 0.3312643 ,
#        0.33095129, 0.33074144, 0.3306681 ])

# %%
ks
# Out:
# [0.4,
#  0.40454545454545454,
#  0.4090909090909091,
#  0.41363636363636364,
#  0.4181818181818182,
#  0.42272727272727273,
#  0.4272727272727273,
#  0.4318181818181818,
#  0.4363636363636364,
#  0.4409090909090909,
#  0.44545454545454544,
#  0.45,
#  0.4545454545454546,
#  0.4590909090909091,
#  0.4636363636363636,
#  0.4681818181818182,
#  0.4727272727272727,
#  0.4772727272727273,
#  0.4818181818181818,
#  0.48636363636363633,
#  0.4909090909090909,
#  0.4954545454545455,
#  0.5]

# %%
(1e-12)*(c/(a*1e-6))*freqs

# %%
for i in range(1,5):
    ez1 = np.real(md.convert(ms.get_efield(i,bloch_phase=False)[:,:,z0,2]))
    maxabsz1 = np.max(abs(ez1))
    plt.figure(figsize=(10,10))
    plt.imshow(ez1.T, cmap='RdBu', vmin=-maxabsz1, vmax=+maxabsz1)
    plt.colorbar()
    plt.show()
    print(i)

# %%
ey1.shape

# %%
np.set_printoptions(threshold=np.inf)

# %%
ey1[1:50,150:600]

# %% [markdown]
# ##### ks = [k.x for k in ms.k_points] # kx wavevector
# plt.figure(figsize=(10,8))
# plt.plot(ks, (1e-12)*(c/(a*1e-6))*freqs, "k-")
# plt.plot([ks[0],ks[-1]],[NV_omega,NV_omega],"k:")
# plt.plot([ks[0],ks[-1]],[ks[0]*c*1e-12/(a*1e-6),ks[-1]*c*1e-12/(a*1e-6)],"k:")
# plt.plot([ks[0],ks[-1]],[ks[0]*c*1e-12/(a*1e-6)/1.45,ks[-1]*c*1e-12/(a*1e-6)/1.45],"k:")
# plt.xlabel("$k_x (2\pi/a)$")
# plt.ylabel("$f$ (THz)")
# plt.title('simtype')
# plt.show()

# %%
(1e-12)*c/(637e-9)

# %%
(1e-12)*(c/(a*1e-6))*freqs[:,2]

# %%
ks

# %%
c/((470.6357359-470.62455397)*1e12*2*3.1415926/(2*3.1415926/(0.184*1e-6)*(0.5-0.49)/42))

# %%
(1e-12)*(3e8/(1*1e-6))*0.5
